# %% [markdown]
# ## Notebook: Transform dữ liệu từ tầng broze lên tầng silver

# %% [markdown]
# ### 1: Import & Connect DB

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.types import BigInteger, VARCHAR, DateTime, Text
from dotenv import load_dotenv

load_dotenv()

DB_USER   = os.getenv("DB_USER")
DB_PASS   = os.getenv("DB_PASS")
DB_HOST   = os.getenv("DB_HOST")
DB_PORT   = os.getenv("DB_PORT")
DB_BRONZE = os.getenv("DB_BRONZE")
DB_SILVER = os.getenv("DB_SILVER")

bronze_engine = create_engine(f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_BRONZE}")
silver_engine = create_engine(f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_SILVER}")

# %% [markdown]
# ### 2. Load raw shops từ Bronze

# %%
shops_df = pd.read_sql("SELECT * FROM shops_raw", bronze_engine)
print("Shape:", shops_df.shape)

# Xem 1 record mẫu
print(json.dumps(json.loads(shops_df["raw_json"].iloc[0]), indent=2, ensure_ascii=False))
# Out:
# Shape: (1, 3)
# {
#   "avatar_url": "https://content.pancake.vn/2-24/2024/2/4/e0b42ce77a7b7922388df987610dbf255705a744.png",
#   "currency": "VND",
#   "id": 230361475,
#   "link_post_marketer": [],
#   "name": "Winner Group",
#   "pages": [
#     {
#       "id": "490071977529040",
#       "is_onboard_xendit": null,
#       "name": "LiLi Store",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "vz+8J5GNL2xQu78S"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#4b5577",
#           "id": 0,
#           "lighten_color": "#c9ccd6",
#           "text": "Kiểm hàng"
#         },
#         {
#           "color": "#a1992b",
#           "id": 1,
#           "lighten_color": "rgba(161,153,43,0.4)",
#           "text": "Thanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#58df63",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(88,223,99,0.4)",
#           "text": "Tuyết"
#         },
#         {
#           "color": "#252525",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(37,37,37,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#1890ff",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#77149e",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(119,20,158,0.4)",
#           "text": "trinhhh"
#         },
#         {
#           "color": "#ff7a45",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(255,122,69,0.4)",
#           "text": "BNGỌC"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 11,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 12,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "535651999625592",
#       "is_onboard_xendit": null,
#       "name": "Quần áo nam cao cấp ",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "lm5XzbvQlU9jFuIE"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#1c5d29",
#           "id": 0,
#           "lighten_color": "rgba(28,93,41,0.4)",
#           "text": "VÂN"
#         },
#         {
#           "color": "#a18c2b",
#           "id": 1,
#           "lighten_color": "rgba(161,140,43,0.4)",
#           "text": "Thanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Hạnhhh"
#         },
#         {
#           "color": "#49d564",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(73,213,100,0.4)",
#           "text": "Tuyết"
#         },
#         {
#           "color": "#9254de",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(146,84,222,0.4)",
#           "text": "trinhhhh"
#         },
#         {
#           "color": "#2e2f2f",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(46,47,47,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#ff7a45",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(255,122,69,0.4)",
#           "text": "BNGỌC"
#         },
#         {
#           "color": "#1890ff",
#           "id": 11,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 12,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 13,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         }
#       ],
#       "username": "qancc13"
#     },
#     {
#       "id": "461234203738139",
#       "is_onboard_xendit": null,
#       "name": "Fame Outlet",
#       "platform": "facebook",
#       "progressive_catalog_error": null,
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "OckkPU8Wc/Fe/nwQ"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#1c5d29",
#           "id": 0,
#           "lighten_color": "rgba(28,93,41,0.4)",
#           "text": "VÂN"
#         },
#         {
#           "color": "#a1952b",
#           "id": 1,
#           "lighten_color": "rgba(161,149,43,0.4)",
#           "text": "THanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Hạnhhh"
#         },
#         {
#           "color": "#171616",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(23,22,22,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#4ede42",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(78,222,66,0.4)",
#           "text": "Tuyết "
#         },
#         {
#           "color": "#ff7a45",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(255,122,69,0.4)",
#           "text": "BNGỌC"
#         },
#         {
#           "color": "#9254de",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(146,84,222,0.4)",
#           "text": "trinhhh"
#         },
#         {
#           "color": "#1890ff",
#           "id": 11,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 12,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 13,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 14,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         }
#       ],
#       "username": "fameo28"
#     },
#     {
#       "id": "523667034155038",
#       "is_onboard_xendit": null,
#       "name": "Nam - Auth USA",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "oyYG6exnqjvbbEpH"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#1c5d29",
#           "id": 0,
#           "lighten_color": "rgba(28,93,41,0.4)",
#           "text": "VÂN"
#         },
#         {
#           "color": "#a18c2b",
#           "id": 1,
#           "lighten_color": "rgba(161,140,43,0.4)",
#           "text": "THanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Hạnhh"
#         },
#         {
#           "color": "#3def4e",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(61,239,78,0.4)",
#           "text": "Tuyết"
#         },
#         {
#           "color": "#9254de",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(146,84,222,0.4)",
#           "text": "trinh"
#         },
#         {
#           "color": "#0a0a0a",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(10,10,10,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#1890ff",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#de279b",
#           "id": 11,
#           "is_lead_event": false,
#           "lighten_color": "rgba(222,39,155,0.4)",
#           "text": "BNGỌC"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 12,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 13,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         }
#       ],
#       "username": "Namauth26"
#     },
#     {
#       "id": "388599531008655",
#       "is_onboard_xendit": null,
#       "name": "Men's Fashion",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "AI1EOv2JxCzTlsRc"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#1c5d29",
#           "id": 0,
#           "lighten_color": "rgba(28,93,41,0.4)",
#           "text": "VÂN"
#         },
#         {
#           "color": "#822ba1",
#           "id": 1,
#           "lighten_color": "#d9bfe2",
#           "text": "Câu hỏi"
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Hạnhhh"
#         },
#         {
#           "color": "#191918",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(25,25,24,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#1890ff",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#9254de",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(146,84,222,0.4)",
#           "text": "trinh"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 11,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "418348241360099",
#       "is_onboard_xendit": null,
#       "name": "Nam Hoàng - Authentic",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "QFZuwQtTsyrtjrgf"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#4b5577",
#           "id": 0,
#           "lighten_color": "#c9ccd6",
#           "text": "VÂN"
#         },
#         {
#           "color": "#a1882b",
#           "id": 1,
#           "lighten_color": "rgba(161,136,43,0.4)",
#           "text": "THanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#232321",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(35,35,33,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "415171811683780",
#       "is_onboard_xendit": null,
#       "name": "Ánh Aut",
#       "platform": "facebook",
#       "progressive_catalog_error": null,
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "d/Try6v/8V9/gERV"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#1c5d29",
#           "id": 0,
#           "lighten_color": "rgba(28,93,41,0.4)",
#           "text": "VÂN"
#         },
#         {
#           "color": "#a1992b",
#           "id": 1,
#           "lighten_color": "rgba(161,153,43,0.4)",
#           "text": "THanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Hạnhhh"
#         },
#         {
#           "color": "#9254de",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(146,84,222,0.4)",
#           "text": "trinhhh"
#         },
#         {
#           "color": "#30fc60",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(48,252,96,0.4)",
#           "text": "Tuyết"
#         },
#         {
#           "color": "#1e1e1f",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(30,30,31,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#1890ff",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#ffc53d",
#           "id": 11,
#           "is_lead_event": false,
#           "lighten_color": "rgba(255,197,61,0.4)",
#           "text": "Trà"
#         },
#         {
#           "color": "#de279b",
#           "id": 12,
#           "is_lead_event": false,
#           "lighten_color": "rgba(222,39,155,0.4)",
#           "text": "BNGỌC"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 13,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 14,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "428937593641266",
#       "is_onboard_xendit": null,
#       "name": "Kavani Store",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "D6JnBdveTG30YmF5"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#4b5577",
#           "id": 0,
#           "lighten_color": "#c9ccd6",
#           "text": "VÂN"
#         },
#         {
#           "color": "#a1882b",
#           "id": 1,
#           "lighten_color": "rgba(161,136,43,0.4)",
#           "text": "Thanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Hạnhhh"
#         },
#         {
#           "color": "#b727bd",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(183,39,189,0.4)",
#           "text": "trinhh"
#         },
#         {
#           "color": "#131312",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,19,18,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#35e351",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(53,227,81,0.4)",
#           "text": "Tuyết"
#         },
#         {
#           "color": "#1890ff",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 11,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 12,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "lv_230361475",
#       "is_onboard_xendit": null,
#       "name": "Winner Group",
#       "platform": "levera",
#       "progressive_catalog_error": null,
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "ATCs3U21vaeqLQif"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#4b5577",
#           "id": 0,
#           "lighten_color": "#c9ccd6",
#           "text": "Kiểm hàng"
#         },
#         {
#           "color": "#822ba1",
#           "id": 1,
#           "lighten_color": "#d9bfe2",
#           "text": "Câu hỏi"
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "Trả hàng"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "425995983931039",
#       "is_onboard_xendit": null,
#       "name": "Kho Xả Hàng Giá Gốc",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "ZqUjrOyicf1+KbBt"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#4b5577",
#           "id": 0,
#           "lighten_color": "#c9ccd6",
#           "text": "Kiểm hàng"
#         },
#         {
#           "color": "#822ba1",
#           "id": 1,
#           "lighten_color": "#d9bfe2",
#           "text": "Câu hỏi"
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#1f1e20",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(31,30,32,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#c637ca",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(198,55,202,0.4)",
#           "text": "Trinhhh"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "418191864715327",
#       "is_onboard_xendit": null,
#       "name": "Tổng kho xả hàng thanh lý xuất dư",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "yV1P37x9VNnhuoR8"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#4b5577",
#           "id": 0,
#           "lighten_color": "#c9ccd6",
#           "text": "VÂN"
#         },
#         {
#           "color": "#a1872b",
#           "id": 1,
#           "lighten_color": "rgba(161,135,43,0.4)",
#           "text": "THanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#1c1c1b",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(28,28,27,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#1890ff",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#de52ed",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(222,82,237,0.4)",
#           "text": "Trinhhh"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Hạnhhh"
#         },
#         {
#           "color": "#ffc53d",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(255,197,61,0.4)",
#           "text": "Sáu"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "428194993710941",
#       "is_onboard_xendit": null,
#       "name": "D&Đ - Chuyên Hàng Xách Tay US",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "f3KPqwIiIDl0H9bB"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#1c5d29",
#           "id": 0,
#           "lighten_color": "rgba(28,93,41,0.4)",
#           "text": "VÂN"
#         },
#         {
#           "color": "#a1832b",
#           "id": 1,
#           "lighten_color": "rgba(161,131,43,0.4)",
#           "text": "THanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Hạnhhh"
#         },
#         {
#           "color": "#1890ff",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#0b0b0b",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(11,11,11,0.4)",
#           "text": "Khánh "
#         },
#         {
#           "color": "#ffc53d",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(255,197,61,0.4)",
#           "text": "Sáu"
#         },
#         {
#           "color": "#45d732",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(69,215,50,0.4)",
#           "text": "Tuyết"
#         },
#         {
#           "color": "#fa8c16",
#           "id": 11,
#           "is_lead_event": false,
#           "lighten_color": "rgba(250,140,22,0.4)",
#           "text": "Trinh"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 12,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 13,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 14,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "438621575994588",
#       "is_onboard_xendit": null,
#       "name": "Tuấn Anh Authentic",
#       "platform": "facebook",
#       "progressive_catalog_error": null,
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "8NV+Bu6k4huKKnTh"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#1c5d29",
#           "id": 0,
#           "lighten_color": "rgba(28,93,41,0.4)",
#           "text": "VÂN"
#         },
#         {
#           "color": "#a1902b",
#           "id": 1,
#           "lighten_color": "rgba(161,144,43,0.4)",
#           "text": "THanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Hạnhhh"
#         },
#         {
#           "color": "#0d0d0d",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(13,13,13,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#ffc53d",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(255,197,61,0.4)",
#           "text": "Sáu"
#         },
#         {
#           "color": "#38d866",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(56,216,102,0.4)",
#           "text": "Tuyết "
#         },
#         {
#           "color": "#1890ff",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#fa8c16",
#           "id": 11,
#           "is_lead_event": false,
#           "lighten_color": "rgba(250,140,22,0.4)",
#           "text": "trinh"
#         },
#         {
#           "color": "#de279b",
#           "id": 12,
#           "is_lead_event": false,
#           "lighten_color": "rgba(222,39,155,0.4)",
#           "text": "BNGỌC"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "104020928940913",
#       "is_onboard_xendit": null,
#       "name": "Emmy Fashion",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "lUKq/QGVZrpe43lP"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#3ba12b",
#           "id": 6,
#           "lighten_color": "rgba(59,161,43,0.4)",
#           "text": "Chốt đơn"
#         },
#         {
#           "color": "#f608f3",
#           "id": 7,
#           "lighten_color": "rgba(246,8,243,0.4)",
#           "text": "Quan tâm"
#         },
#         {
#           "color": "#4b5577",
#           "id": 8,
#           "lighten_color": "rgba(75,85,119,0.4)",
#           "text": "đơn 1"
#         },
#         {
#           "color": "#b1b00d",
#           "id": 9,
#           "lighten_color": "rgba(177,176,13,0.4)",
#           "text": "đơn 2"
#         },
#         {
#           "color": "#4b5577",
#           "id": 10,
#           "lighten_color": "rgba(75,85,119,0.4)",
#           "text": "đơn 3"
#         },
#         {
#           "color": "#0d5aff",
#           "id": 11,
#           "lighten_color": "rgba(13,90,255,0.4)",
#           "text": "đơn 4"
#         },
#         {
#           "color": "#cec700",
#           "id": 12,
#           "lighten_color": "rgba(206,199,0,0.4)",
#           "text": "đã gọi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 13,
#           "lighten_color": "rgba(56,166,244,0.4)",
#           "text": "Hết size"
#         },
#         {
#           "color": "#85021d",
#           "id": 14,
#           "lighten_color": "rgba(133,2,29,0.4)",
#           "text": "Trùng đơn"
#         },
#         {
#           "color": "#057f48",
#           "id": 18,
#           "lighten_color": "rgba(5,127,72,0.4)",
#           "text": "Vân"
#         },
#         {
#           "color": "#a49e36",
#           "id": 24,
#           "lighten_color": "rgba(164,158,54,0.4)",
#           "text": "Thanh "
#         },
#         {
#           "color": "#b42e2e",
#           "id": 26,
#           "lighten_color": "rgba(180,46,46,0.4)",
#           "text": "Hường"
#         },
#         {
#           "color": "#0cf218",
#           "id": 29,
#           "lighten_color": "rgba(12,242,24,0.4)",
#           "text": "Mạnh"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 30,
#           "lighten_color": "rgba(56,166,244,0.4)",
#           "text": "Đơn lâu"
#         },
#         {
#           "color": "#e7a62a",
#           "id": 31,
#           "is_lead_event": false,
#           "lighten_color": "rgba(231,166,42,0.4)",
#           "text": "BÁCH"
#         },
#         {
#           "color": "#f43838",
#           "id": 32,
#           "is_lead_event": false,
#           "lighten_color": "rgba(244,56,56,0.4)",
#           "text": "MHAO"
#         },
#         {
#           "color": "#b1710d",
#           "id": 33,
#           "is_lead_event": false,
#           "lighten_color": "rgba(177,113,13,0.4)",
#           "text": "Tuyết "
#         },
#         {
#           "color": "#891766",
#           "id": 34,
#           "is_lead_event": false,
#           "lighten_color": "rgba(137,23,102,0.4)",
#           "text": "Hạnh"
#         },
#         {
#           "color": "#151212",
#           "id": 35,
#           "is_lead_event": false,
#           "lighten_color": "rgba(21,18,18,0.4)",
#           "text": "Khánh "
#         },
#         {
#           "color": "#cec700",
#           "id": 36,
#           "is_lead_event": false,
#           "lighten_color": "rgba(206,199,0,0.4)",
#           "text": "ngoc"
#         }
#       ],
#       "username": "EmmyFashionst1"
#     },
#     {
#       "id": "101651149319027",
#       "is_onboard_xendit": null,
#       "name": "Elly Fashion",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "8e4FhuB5gykW3ShD"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#ee1616",
#           "id": 19,
#           "lighten_color": "rgba(238,22,22,0.4)",
#           "text": "MHAO"
#         },
#         {
#           "color": "#ef5798",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(239,87,152,0.4)",
#           "text": "LIÊN"
#         },
#         {
#           "color": "#3ba12b",
#           "id": 7,
#           "lighten_color": "rgba(59,161,43,0.4)",
#           "text": "Chốt đơn"
#         },
#         {
#           "color": "#4b5577",
#           "id": 9,
#           "lighten_color": "rgba(75,85,119,0.4)",
#           "text": "đơn 1"
#         },
#         {
#           "color": "#b1b00d",
#           "id": 10,
#           "lighten_color": "rgba(177,176,13,0.4)",
#           "text": "đơn 2"
#         },
#         {
#           "color": "#4b5577",
#           "id": 11,
#           "lighten_color": "rgba(75,85,119,0.4)",
#           "text": "đơn 3"
#         },
#         {
#           "color": "#0d5aff",
#           "id": 12,
#           "lighten_color": "rgba(13,90,255,0.4)",
#           "text": "đơn 4"
#         },
#         {
#           "color": "#cec700",
#           "id": 13,
#           "lighten_color": "rgba(206,199,0,0.4)",
#           "text": "đã gọi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 14,
#           "lighten_color": "rgba(56,166,244,0.4)",
#           "text": "Hết size"
#         },
#         {
#           "color": "#85021d",
#           "id": 15,
#           "lighten_color": "rgba(133,2,29,0.4)",
#           "text": "Trùng đơn"
#         },
#         {
#           "color": "#3e813c",
#           "id": 20,
#           "lighten_color": "rgba(62,129,60,0.4)",
#           "text": "Vân"
#         },
#         {
#           "color": "#c67515",
#           "id": 21,
#           "lighten_color": "rgba(198,117,21,0.4)",
#           "text": "Tùng"
#         },
#         {
#           "color": "#f2b207",
#           "id": 22,
#           "lighten_color": "rgba(242,178,7,0.4)",
#           "text": "Ngọc"
#         },
#         {
#           "color": "#1cae67",
#           "id": 42,
#           "is_lead_event": false,
#           "lighten_color": "rgba(28,174,103,0.4)",
#           "text": "Lệ"
#         },
#         {
#           "color": "#a49e36",
#           "id": 23,
#           "lighten_color": "rgba(164,158,54,0.4)",
#           "text": "Thanh "
#         },
#         {
#           "color": "#1550c6",
#           "id": 27,
#           "lighten_color": "rgba(21,80,198,0.4)",
#           "text": "Tuyết"
#         },
#         {
#           "color": "#930086",
#           "id": 28,
#           "lighten_color": "rgba(147,0,134,0.4)",
#           "text": "Hạnh"
#         },
#         {
#           "color": "#2c2235",
#           "id": 31,
#           "is_lead_event": false,
#           "lighten_color": "rgba(44,34,53,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#e7a62a",
#           "id": 32,
#           "is_lead_event": false,
#           "lighten_color": "rgba(231,166,42,0.4)",
#           "text": "BÁCH"
#         },
#         {
#           "color": "#ef5798",
#           "id": 33,
#           "is_lead_event": false,
#           "lighten_color": "rgba(239,87,152,0.4)",
#           "text": "LIÊN"
#         },
#         {
#           "color": "#1550c6",
#           "id": 35,
#           "is_lead_event": false,
#           "lighten_color": "rgba(21,80,198,0.4)",
#           "text": "Sáu"
#         },
#         {
#           "color": "#7b9300",
#           "id": 37,
#           "is_lead_event": false,
#           "lighten_color": "rgba(123,147,0,0.4)",
#           "text": "Phương"
#         },
#         {
#           "color": "#ec1b7b",
#           "id": 44,
#           "is_lead_event": false,
#           "lighten_color": "rgba(236,27,123,0.4)",
#           "text": "Nga"
#         },
#         {
#           "color": "#9254de",
#           "id": 45,
#           "is_lead_event": false,
#           "lighten_color": "rgba(146,84,222,0.4)",
#           "text": "BNgoc"
#         },
#         {
#           "color": "#3295d9",
#           "id": 46,
#           "is_lead_event": false,
#           "lighten_color": "rgba(50,149,217,0.4)",
#           "text": "KLinh"
#         },
#         {
#           "color": "#030659",
#           "id": 47,
#           "is_lead_event": false,
#           "lighten_color": "rgba(3,6,89,0.4)",
#           "text": "Hằng Cáo "
#         },
#         {
#           "color": "#f100cb",
#           "id": 48,
#           "is_lead_event": false,
#           "lighten_color": "rgba(241,0,203,0.4)",
#           "text": "PHƯƠNGGG"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "103155739066932",
#       "is_onboard_xendit": null,
#       "name": "Lina Store",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "S9PCaaewX2k3srw6"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#ee1616",
#           "id": 36,
#           "lighten_color": "rgba(238,22,22,0.4)",
#           "text": "MHAO"
#         },
#         {
#           "color": "#3ba12b",
#           "id": 6,
#           "lighten_color": "rgba(59,161,43,0.4)",
#           "text": "Chốt đơn"
#         },
#         {
#           "color": "#4b5577",
#           "id": 8,
#           "lighten_color": "rgba(75,85,119,0.4)",
#           "text": "đơn 1"
#         },
#         {
#           "color": "#b1b00d",
#           "id": 9,
#           "lighten_color": "rgba(177,176,13,0.4)",
#           "text": "đơn 2"
#         },
#         {
#           "color": "#4b5577",
#           "id": 10,
#           "lighten_color": "rgba(75,85,119,0.4)",
#           "text": "đơn 3"
#         },
#         {
#           "color": "#0d5aff",
#           "id": 11,
#           "lighten_color": "rgba(13,90,255,0.4)",
#           "text": "đơn 4"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 13,
#           "lighten_color": "rgba(56,166,244,0.4)",
#           "text": "Hết size"
#         },
#         {
#           "color": "#3e813c",
#           "id": 18,
#           "lighten_color": "rgba(62,129,60,0.4)",
#           "text": "Vân"
#         },
#         {
#           "color": "#f2b207",
#           "id": 26,
#           "lighten_color": "rgba(242,178,7,0.4)",
#           "text": "Ngọc"
#         },
#         {
#           "color": "#a49e36",
#           "id": 27,
#           "lighten_color": "rgba(164,158,54,0.4)",
#           "text": "Thanh "
#         },
#         {
#           "color": "#1550c6",
#           "id": 35,
#           "lighten_color": "rgba(21,80,198,0.4)",
#           "text": "Tuyết"
#         },
#         {
#           "color": "#e7a62a",
#           "id": 39,
#           "is_lead_event": false,
#           "lighten_color": "rgba(231,166,42,0.4)",
#           "text": "BÁCH"
#         },
#         {
#           "color": "#2c2235",
#           "id": 40,
#           "is_lead_event": false,
#           "lighten_color": "rgba(44,34,53,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#ef5798",
#           "id": 42,
#           "is_lead_event": false,
#           "lighten_color": "rgba(239,87,152,0.4)",
#           "text": "LIÊN"
#         },
#         {
#           "color": "#1cae67",
#           "id": 44,
#           "is_lead_event": false,
#           "lighten_color": "rgba(28,174,103,0.4)",
#           "text": "Lệ"
#         },
#         {
#           "color": "#1550c6",
#           "id": 45,
#           "is_lead_event": false,
#           "lighten_color": "rgba(21,80,198,0.4)",
#           "text": "Sáu"
#         },
#         {
#           "color": "#9254de",
#           "id": 48,
#           "is_lead_event": false,
#           "lighten_color": "rgba(146,84,222,0.4)",
#           "text": "BNgoc"
#         },
#         {
#           "color": "#3295d9",
#           "id": 49,
#           "is_lead_event": false,
#           "lighten_color": "rgba(50,149,217,0.4)",
#           "text": "KLinh"
#         },
#         {
#           "color": "#009344",
#           "id": 50,
#           "is_lead_event": false,
#           "lighten_color": "rgba(0,147,68,0.4)",
#           "text": "Hạnh"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 51,
#           "is_lead_event": false,
#           "lighten_color": "rgba(56,166,244,0.4)",
#           "text": "Hằng Cáo "
#         },
#         {
#           "color": "#ff7a45",
#           "id": 52,
#           "is_lead_event": false,
#           "lighten_color": "rgba(255,122,69,0.4)",
#           "text": "Trinh"
#         },
#         {
#           "color": "#4ce48d",
#           "id": 53,
#           "is_lead_event": false,
#           "lighten_color": "rgba(76,228,141,0.4)",
#           "text": "NHIÊN"
#         },
#         {
#           "color": "#f998e4",
#           "id": 54,
#           "is_lead_event": false,
#           "lighten_color": "rgba(249,152,228,0.4)",
#           "text": "Uyên"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 55,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         },
#         {
#           "color": "#e4ec46",
#           "id": 56,
#           "is_lead_event": false,
#           "lighten_color": "rgba(228,236,70,0.4)",
#           "text": "Huế"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "232280726636005",
#       "is_onboard_xendit": null,
#       "name": "Lina Fashion",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "x8S1XIDlFn5lcW99"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 15,
#           "lighten_color": "rgba(189,39,39,0.4)",
#           "text": "MHAO"
#         },
#         {
#           "color": "#1cae67",
#           "id": 2,
#           "lighten_color": "rgba(28,174,103,0.4)",
#           "text": "Chốt đơn"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#1cae67",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(28,174,103,0.4)",
#           "text": "Lệ"
#         },
#         {
#           "color": "#0d5aff",
#           "id": 9,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#35742e",
#           "id": 13,
#           "lighten_color": "rgba(53,116,46,0.4)",
#           "text": "Vân"
#         },
#         {
#           "color": "#a49e36",
#           "id": 16,
#           "lighten_color": "rgba(164,158,54,0.4)",
#           "text": "Thanh "
#         },
#         {
#           "color": "#ff3030",
#           "id": 17,
#           "lighten_color": "rgba(255,48,48,0.4)",
#           "text": "hường"
#         },
#         {
#           "color": "#38f466",
#           "id": 18,
#           "lighten_color": "rgba(56,244,102,0.4)",
#           "text": "TUYẾT"
#         },
#         {
#           "color": "#774b4c",
#           "id": 19,
#           "lighten_color": "rgba(119,75,76,0.4)",
#           "text": "Hạnh"
#         },
#         {
#           "color": "#131213",
#           "id": 20,
#           "lighten_color": "rgba(19,18,19,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#de9035",
#           "id": 21,
#           "is_lead_event": false,
#           "lighten_color": "rgba(222,144,53,0.4)",
#           "text": "BÁCH"
#         },
#         {
#           "color": "#8b9e14",
#           "id": 22,
#           "is_lead_event": false,
#           "lighten_color": "rgba(139,158,20,0.4)",
#           "text": "ngọc"
#         },
#         {
#           "color": "#ef5798",
#           "id": 23,
#           "is_lead_event": false,
#           "lighten_color": "rgba(239,87,152,0.4)",
#           "text": "Liên"
#         },
#         {
#           "color": "#7b9300",
#           "id": 24,
#           "is_lead_event": false,
#           "lighten_color": "rgba(123,147,0,0.4)",
#           "text": "Phương"
#         },
#         {
#           "color": "#cec700",
#           "id": 26,
#           "is_lead_event": false,
#           "lighten_color": "rgba(206,199,0,0.4)",
#           "text": "Sáu"
#         },
#         {
#           "color": "#ec1b7b",
#           "id": 27,
#           "is_lead_event": false,
#           "lighten_color": "rgba(236,27,123,0.4)",
#           "text": "Nga"
#         },
#         {
#           "color": "#9254de",
#           "id": 28,
#           "is_lead_event": false,
#           "lighten_color": "rgba(146,84,222,0.4)",
#           "text": "BNgoc"
#         },
#         {
#           "color": "#1890ff",
#           "id": 29,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#17adad",
#           "id": 30,
#           "is_lead_event": false,
#           "lighten_color": "rgba(23,173,173,0.4)",
#           "text": "Hà"
#         },
#         {
#           "color": "#030659",
#           "id": 31,
#           "is_lead_event": false,
#           "lighten_color": "rgba(3,6,89,0.4)",
#           "text": "Hằng Cáo "
#         },
#         {
#           "color": "#4b5577",
#           "id": 32,
#           "lighten_color": "#c9ccd6",
#           "text": "Kiểm hàng"
#         },
#         {
#           "color": "#822ba1",
#           "id": 33,
#           "lighten_color": "#d9bfe2",
#           "text": "Câu hỏi"
#         },
#         {
#           "color": "#0d5aff",
#           "id": 34,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 35,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 36,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#bd2727",
#           "id": 37,
#           "lighten_color": "#ebbebe",
#           "text": "Trả hàng"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "108137068137849",
# ...
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "M8kT1X0zibwghgvd"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#3ba12b",
#           "id": 6,
#           "lighten_color": "rgba(59,161,43,0.4)",
#           "text": "Chốt đơn"
#         },
#         {
#           "color": "#f608f3",
#           "id": 7,
#           "lighten_color": "rgba(246,8,243,0.4)",
#           "text": "Quan tâm"
#         },
#         {
#           "color": "#4b5577",
#           "id": 8,
#           "lighten_color": "rgba(75,85,119,0.4)",
#           "text": "đơn 1"
#         },
#         {
#           "color": "#b1b00d",
#           "id": 9,
#           "lighten_color": "rgba(177,176,13,0.4)",
#           "text": "đơn 2"
#         },
#         {
#           "color": "#4b5577",
#           "id": 10,
#           "lighten_color": "rgba(75,85,119,0.4)",
#           "text": "đơn 3"
#         },
#         {
#           "color": "#0d5aff",
#           "id": 11,
#           "lighten_color": "rgba(13,90,255,0.4)",
#           "text": "đơn 4"
#         },
#         {
#           "color": "#cec700",
#           "id": 12,
#           "lighten_color": "rgba(206,199,0,0.4)",
#           "text": "đã gọi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 14,
#           "lighten_color": "rgba(56,166,244,0.4)",
#           "text": "Hết size"
#         },
#         {
#           "color": "#85021d",
#           "id": 15,
#           "lighten_color": "rgba(133,2,29,0.4)",
#           "text": "Trùng đơn"
#         },
#         {
#           "color": "#dbd739",
#           "id": 16,
#           "lighten_color": "rgba(219,215,57,0.4)",
#           "text": "Xuyến"
#         },
#         {
#           "color": "#ff306a",
#           "id": 17,
#           "lighten_color": "rgba(255,48,106,0.4)",
#           "text": "Dung"
#         },
#         {
#           "color": "#fca026",
#           "id": 13,
#           "lighten_color": "rgba(252,160,38,0.4)",
#           "text": "Khánh Ly"
#         },
#         {
#           "color": "#f2b207",
#           "id": 18,
#           "lighten_color": "rgba(242,178,7,0.4)",
#           "text": "Ngọc"
#         },
#         {
#           "color": "#a49e36",
#           "id": 19,
#           "lighten_color": "rgba(164,158,54,0.4)",
#           "text": "Thanh "
#         },
#         {
#           "color": "#5fcbea",
#           "id": 20,
#           "lighten_color": "rgba(95,203,234,0.4)",
#           "text": "Thu"
#         },
#         {
#           "color": "#c67515",
#           "id": 21,
#           "lighten_color": "rgba(198,117,21,0.4)",
#           "text": "Tùng"
#         },
#         {
#           "color": "#822ba1",
#           "id": 22,
#           "lighten_color": "rgba(130,43,161,0.4)",
#           "text": "Lan"
#         },
#         {
#           "color": "#01ce00",
#           "id": 23,
#           "lighten_color": "rgba(1,206,0,0.4)",
#           "text": "Vân"
#         },
#         {
#           "color": "#07fff0",
#           "id": 24,
#           "lighten_color": "rgba(7,255,240,0.4)",
#           "text": "Hân em"
#         },
#         {
#           "color": "#b42e2e",
#           "id": 25,
#           "lighten_color": "rgba(180,46,46,0.4)",
#           "text": "Hường"
#         },
#         {
#           "color": "#779e14",
#           "id": 26,
#           "lighten_color": "rgba(119,158,20,0.4)",
#           "text": "Hà"
#         },
#         {
#           "color": "#6c1f87",
#           "id": 27,
#           "lighten_color": "rgba(108,31,135,0.4)",
#           "text": "phương"
#         },
#         {
#           "color": "#77149e",
#           "id": 28,
#           "lighten_color": "rgba(119,20,158,0.4)",
#           "text": "Đòi hàng"
#         },
#         {
#           "color": "#4b776a",
#           "id": 29,
#           "lighten_color": "rgba(75,119,106,0.4)",
#           "text": "Trang "
#         },
#         {
#           "color": "#4b776a",
#           "id": 30,
#           "lighten_color": "rgba(75,119,106,0.4)",
#           "text": "Trang "
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "110714598677928",
#       "is_onboard_xendit": null,
#       "name": "Gumacc Store",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "w+PQEHzjKYOjUsDu"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 6,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#fa8c16",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(250,140,22,0.4)",
#           "text": "BÁCHHH"
#         },
#         {
#           "color": "#1890ff",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#ef5798",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(239,87,152,0.4)",
#           "text": "LIÊN"
#         },
#         {
#           "color": "#131314",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,19,20,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#ff7a45",
#           "id": 11,
#           "is_lead_event": false,
#           "lighten_color": "rgba(255,122,69,0.4)",
#           "text": "Hạnh"
#         },
#         {
#           "color": "#9254de",
#           "id": 12,
#           "is_lead_event": false,
#           "lighten_color": "rgba(146,84,222,0.4)",
#           "text": "BNgoc"
#         },
#         {
#           "color": "#0e2f44",
#           "id": 13,
#           "is_lead_event": false,
#           "lighten_color": "rgba(14,47,68,0.4)",
#           "text": "ngoc"
#         },
#         {
#           "color": "#0d5aff",
#           "id": 14,
#           "is_lead_event": false,
#           "lighten_color": "rgba(13,90,255,0.4)",
#           "text": "Sáu "
#         },
#         {
#           "color": "#1cae67",
#           "id": 15,
#           "is_lead_event": false,
#           "lighten_color": "rgba(28,174,103,0.4)",
#           "text": "VÂN"
#         },
#         {
#           "color": "#2bee38",
#           "id": 16,
#           "is_lead_event": false,
#           "lighten_color": "rgba(43,238,56,0.4)",
#           "text": "Tuyết"
#         },
#         {
#           "color": "#8d9621",
#           "id": 17,
#           "is_lead_event": false,
#           "lighten_color": "rgba(141,150,33,0.4)",
#           "text": "Thanh"
#         },
#         {
#           "color": "#17adad",
#           "id": 18,
#           "is_lead_event": false,
#           "lighten_color": "rgba(23,173,173,0.4)",
#           "text": "Hà"
#         },
#         {
#           "color": "#1890ff",
#           "id": 19,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#9254de",
#           "id": 20,
#           "is_lead_event": false,
#           "lighten_color": "rgba(146,84,222,0.4)",
#           "text": "BNgoc"
#         },
#         {
#           "color": "#4ce48d",
#           "id": 21,
#           "is_lead_event": false,
#           "lighten_color": "rgba(76,228,141,0.4)",
#           "text": "NHIÊN"
#         },
#         {
#           "color": "#f998e4",
#           "id": 22,
#           "is_lead_event": false,
#           "lighten_color": "rgba(249,152,228,0.4)",
#           "text": "Uyên"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "324518484071667",
#       "is_onboard_xendit": null,
#       "name": "Gạo Linen",
#       "platform": "facebook",
#       "progressive_catalog_error": null,
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "T9b0LeDAmNwT7EVU"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#175500",
#           "id": 0,
#           "lighten_color": "rgba(23,85,0,0.4)",
#           "text": "VÂN"
#         },
#         {
#           "color": "#a17f2b",
#           "id": 1,
#           "lighten_color": "rgba(161,127,43,0.4)",
#           "text": "Thanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#1e1c1c",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(30,28,28,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Hạnhhh"
#         },
#         {
#           "color": "#178989",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(23,137,137,0.4)",
#           "text": "ngoc"
#         },
#         {
#           "color": "#6dec61",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(109,236,97,0.4)",
#           "text": "Tuyết"
#         },
#         {
#           "color": "#1890ff",
#           "id": 11,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#1cae67",
#           "id": 12,
#           "is_lead_event": false,
#           "lighten_color": "rgba(28,174,103,0.4)",
#           "text": "Sáu"
#         },
#         {
#           "color": "#f100cb",
#           "id": 14,
#           "is_lead_event": false,
#           "lighten_color": "rgba(241,0,203,0.4)",
#           "text": "PHƯƠNGGG"
#         },
#         {
#           "color": "#fa8c16",
#           "id": 15,
#           "is_lead_event": false,
#           "lighten_color": "rgba(250,140,22,0.4)",
#           "text": "trinh"
#         },
#         {
#           "color": "#de279b",
#           "id": 16,
#           "is_lead_event": false,
#           "lighten_color": "rgba(222,39,155,0.4)",
#           "text": "BNGỌC"
#         }
#       ],
#       "username": "gaolinen"
#     },
#     {
#       "id": "343305455531760",
#       "is_onboard_xendit": null,
#       "name": "Huỳnh Ngân Store",
#       "platform": "facebook",
#       "progressive_catalog_error": "missing_business_id",
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "174s09niAJPC98fG"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#0e4907",
#           "id": 0,
#           "lighten_color": "rgba(14,73,7,0.4)",
#           "text": "VÂN"
#         },
#         {
#           "color": "#a1952b",
#           "id": 1,
#           "lighten_color": "rgba(161,149,43,0.4)",
#           "text": "Thanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Hạnhhh"
#         },
#         {
#           "color": "#171716",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(23,23,22,0.4)",
#           "text": "khánh"
#         },
#         {
#           "color": "#1890ff",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Sáu"
#         },
#         {
#           "color": "#56f567",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(86,245,103,0.4)",
#           "text": "Tuyết"
#         },
#         {
#           "color": "#138809",
#           "id": 12,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,136,9,0.4)",
#           "text": "ngoc"
#         },
#         {
#           "color": "#4b595e",
#           "id": 13,
#           "is_lead_event": false,
#           "lighten_color": "rgba(75,89,94,0.4)",
#           "text": "ngoc"
#         },
#         {
#           "color": "#f100cb",
#           "id": 14,
#           "is_lead_event": false,
#           "lighten_color": "rgba(241,0,203,0.4)",
#           "text": "PHƯƠNGGG"
#         },
#         {
#           "color": "#4ce48d",
#           "id": 15,
#           "is_lead_event": false,
#           "lighten_color": "rgba(76,228,141,0.4)",
#           "text": "NHIÊN"
#         },
#         {
#           "color": "#f998e4",
#           "id": 16,
#           "is_lead_event": false,
#           "lighten_color": "rgba(249,152,228,0.4)",
#           "text": "Uyên"
#         }
#       ],
#       "username": null
#     },
#     {
#       "id": "321861037683480",
#       "is_onboard_xendit": null,
#       "name": "HoaTràCủChi - Shophoatrà",
#       "platform": "facebook",
#       "progressive_catalog_error": null,
#       "settings": {
#         "auto_create_order": true,
#         "current_settings_key": "Add7EHC6zY5d/g60"
#       },
#       "shop_id": 230361475,
#       "tags": [
#         {
#           "color": "#bd2727",
#           "id": 5,
#           "lighten_color": "#ebbebe",
#           "text": "MHAO"
#         },
#         {
#           "color": "#3d7500",
#           "id": 0,
#           "lighten_color": "rgba(61,117,0,0.4)",
#           "text": "VÂN"
#         },
#         {
#           "color": "#9ea12b",
#           "id": 1,
#           "lighten_color": "rgba(158,161,43,0.4)",
#           "text": "THanh "
#         },
#         {
#           "color": "#0d5aff",
#           "id": 2,
#           "lighten_color": "#b6cdff",
#           "text": "Mua hàng"
#         },
#         {
#           "color": "#009344",
#           "id": 3,
#           "lighten_color": "#b2dec6",
#           "text": "Đã gửi"
#         },
#         {
#           "color": "#38a6f4",
#           "id": 4,
#           "lighten_color": "#c3e4fb",
#           "text": "Hết hàng"
#         },
#         {
#           "color": "#f100cb",
#           "id": 6,
#           "is_lead_event": false,
#           "lighten_color": "rgba(241,0,203,0.4)",
#           "text": "PHƯƠNGGG"
#         },
#         {
#           "color": "#1e1d1e",
#           "id": 7,
#           "is_lead_event": false,
#           "lighten_color": "rgba(30,29,30,0.4)",
#           "text": "Khánh"
#         },
#         {
#           "color": "#13c2c2",
#           "id": 8,
#           "is_lead_event": false,
#           "lighten_color": "rgba(19,194,194,0.4)",
#           "text": "Hạnhhh"
#         },
#         {
#           "color": "#1890ff",
#           "id": 9,
#           "is_lead_event": false,
#           "lighten_color": "rgba(24,144,255,0.4)",
#           "text": "KLINH"
#         },
#         {
#           "color": "#ff7a45",
#           "id": 10,
#           "is_lead_event": false,
#           "lighten_color": "rgba(255,122,69,0.4)",
#           "text": "Sáu"
#         },
#         {
#           "color": "#10ff0d",
#           "id": 11,
#           "is_lead_event": false,
#           "lighten_color": "rgba(16,255,13,0.4)",
#           "text": "Tuyết"
#         },
#         {
#           "color": "#822ba1",
#           "id": 12,
#           "is_lead_event": false,
#           "lighten_color": "rgba(130,43,161,0.4)",
#           "text": "ngoc"
#         }
#       ],
#       "username": null
#     }
#   ]
# }

# %% [markdown]
# ### 3. Liệt kê keys JSON (shops)

# %%
all_keys = set()
for raw in shops_df["raw_json"].head(20):  # scan 20 bản ghi đầu
    d = json.loads(raw)
    all_keys.update(d.keys())

print("===== Tổng số keys:", len(all_keys), " =====")
print(sorted(all_keys))
# Out:
# ===== Tổng số keys: 6  =====
# ['avatar_url', 'currency', 'id', 'link_post_marketer', 'name', 'pages']

# %% [markdown]
# ### 4. Parse dim_shops

# %%
def parse_shop(row):
    d = json.loads(row["raw_json"])
    return {
        "shop_id": d.get("id"),
        "shop_name": d.get("name"),
        "currency": d.get("currency"),
        "avatar_url": d.get("avatar_url")
    }

dim_shops = shops_df.apply(parse_shop, axis=1, result_type="expand").drop_duplicates("shop_id")
print("✅ dim_shops shape:", dim_shops.shape)
display(dim_shops.head())
# Out:
# ✅ dim_shops shape: (1, 4)
#      shop_id     shop_name currency  \
# 0  230361475  Winner Group      VND
#
#                                           avatar_url
# 0  https://content.pancake.vn/2-24/2024/2/4/e0b42...

# %% [markdown]
# ### 5. Load vào Silver

# %%
dtype_dim_shops = {
    "shop_id": BigInteger(),
    "shop_name": VARCHAR(255),
    "currency": VARCHAR(10),
    "avatar_url": VARCHAR(500)
}

dim_shops.to_sql(
    "dim_shops",
    con=silver_engine,
    if_exists="replace",
    index=False,
    dtype=dtype_dim_shops
)

print("✅ Loaded to Silver.dim_shops")
# Out:
# ✅ Loaded to Silver.dim_shops
