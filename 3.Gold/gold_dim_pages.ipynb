# %%
# ==========================
# 1. Import & Kết nối DB
# ==========================
import os
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv

# Load biến môi trường
load_dotenv()

DB_USER   = os.getenv("DB_USER")
DB_PASS   = os.getenv("DB_PASS")
DB_HOST   = os.getenv("DB_HOST")
DB_PORT   = os.getenv("DB_PORT")
DB_SILVER = os.getenv("DB_SILVER")
DB_GOLD   = os.getenv("DB_GOLD")

engine_silver = create_engine(
    f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_SILVER}"
)
engine_gold = create_engine(
    f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_GOLD}"
)

# %%
# ==========================
# 2. Load dim_pages từ Silver
# ==========================
query = "SELECT * FROM dim_pages"
df_pages = pd.read_sql(query, engine_silver)

print("Shape:", df_pages.shape)
df_pages.head(10)
# Out:
# Shape: (74, 5)
#            page_id                      page_name         page_username  \
# 0  377626778776391             Duy Mạnh Authentic         duymanhauth10
# 1  492088430643389                     Sùn Outlet               sunoutl
# 2  433231143199907                 Đăng Authentic          dangauth2006
# 3  491931647329576               Famous Authentic   famousauthentic1907
# 4  454214751109901        Săn hàng hiệu US giá rẻ            SanHangUs2
# 5  428194993710941  D&Đ - Chuyên Hàng Xách Tay US                  None
# 6  461234203738139                    Fame Outlet               fameo28
# 7  418470191354740               Hào Nam Authenio   haonamauthentio1907
# 8  526129833907763            Gentleman’s Couture  gentlemancouture1907
# 9  491458047386615            Sùn Hàng Hiệu Oulet               thunusa
#
#            account                   account_name
# 0  377626778776391             Duy Mạnh Authentic
# 1  492088430643389                     Sùn Outlet
# 2  433231143199907                 Đăng Authentic
# 3  491931647329576               Famous Authentic
# 4  454214751109901        Săn hàng hiệu US giá rẻ
# 5  428194993710941  D&Đ - Chuyên Hàng Xách Tay US
# 6  461234203738139                    Fame Outlet
# 7  418470191354740               Hào Nam Authenio
# 8  526129833907763            Gentleman’s Couture
# 9  491458047386615            Sùn Hàng Hiệu Oulet

# %%
# ==========================
# 3. Khám phá dữ liệu
# ==========================
df_pages.info()
df_pages.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   page_id        73 non-null     object
#  1   page_name      73 non-null     object
#  2   page_username  33 non-null     object
#  3   account        73 non-null     object
#  4   account_name   74 non-null     object
# dtypes: object(5)
# memory usage: 3.0+ KB
#                 page_id          page_name  page_username          account  \
# count                73                 73             33               73
# unique               73                 72             33               73
# top     377626778776391  Xưởng May Kim Anh  duymanhauth10  377626778776391
# freq                  1                  2              1                1
#
#              account_name
# count                  74
# unique                 73
# top     Xưởng May Kim Anh
# freq                    2

# %%
# ==========================
# Transform dim_pages → gold_dim_pages
# ==========================
def transform_pages(df):
    df = df.copy()

    # B1. Loại bỏ record thiếu page_id hoặc page_name
    df = df.dropna(subset=['page_id', 'page_name'])

    # B2. Chuẩn hóa text
    df['page_name'] = df['page_name'].str.strip().str.title()
    if 'page_username' in df.columns:
        df['page_username'] = df['page_username'].str.strip().str.lower()


    # B4. Giữ lại cột quan trọng
    keep_cols = [
        'page_id', 'page_name', 'page_username', 
        'account', 'account_name'
    ]
    df_gold = df[keep_cols]

    return df_gold

# %%
df_gold_pages = transform_pages(df_pages)
df_gold_pages
# Out:
#             page_id                page_name        page_username  \
# 0   377626778776391       Duy Mạnh Authentic        duymanhauth10
# 1   492088430643389               Sùn Outlet              sunoutl
# 2   433231143199907           Đăng Authentic         dangauth2006
# 3   491931647329576         Famous Authentic  famousauthentic1907
# 4   454214751109901  Săn Hàng Hiệu Us Giá Rẻ           sanhangus2
# ..              ...                      ...                  ...
# 69  104093599354419             Anh Thư Shop                 None
# 70  110406248113415        Xưởng May Kim Anh    kimanh.thuonghieu
# 71  241364392389685           Patino'S Store                 None
# 72  104020928940913             Emmy Fashion       emmyfashionst1
# 73  100301802118634           Lan Ngọc Store                 None
#
#             account             account_name
# 0   377626778776391       Duy Mạnh Authentic
# 1   492088430643389               Sùn Outlet
# 2   433231143199907           Đăng Authentic
# 3   491931647329576         Famous Authentic
# 4   454214751109901  Săn hàng hiệu US giá rẻ
# ..              ...                      ...
# 69  104093599354419             Anh Thư Shop
# 70  110406248113415        Xưởng May Kim Anh
# 71  241364392389685           Patino's Store
# 72  104020928940913             Emmy Fashion
# 73  100301802118634           Lan Ngọc Store
#
# [73 rows x 5 columns]

# %%
# load vào Gold
df_gold_pages.to_sql(
    "gold_dim_pages",
    engine_gold,
    if_exists="replace",
    index=False
)
# Out:
# 73
